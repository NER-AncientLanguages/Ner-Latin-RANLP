# %% [markdown]
# # SpaCy test

# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# !pip install https://huggingface.co/latincy/la_core_web_lg/resolve/main/la_core_web_lg-any-py3-none-any.whl
import spacy
nlp = spacy.load('la_core_web_lg', exclude=['morphologizer', 'trainable_lemmatizer', 'parser', 'tagger', 'lemma_fixer'])
print(nlp.pipeline)
# doc = nlp('Haec narrantur a poetis de Perseo')
# Out:
# [('normer', <function normer at 0x00000185316DCA40>), ('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec object at 0x0000018566306510>), ('ner', <spacy.pipeline.ner.EntityRecognizer object at 0x0000018566300F20>)]

# %%
# for token in doc:
#     print(token.lemma_)

# %%
from spacy.tokens import Doc

class WhitespaceTokenizer:
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        words = text.split(" ")
        spaces = [True] * len(words)
        # Avoid zero-length tokens
        for i, word in enumerate(words):
            if word == "":
                words[i] = " "
                spaces[i] = False
        # Remove the final trailing space
        if words[-1] == " ":
            words = words[0:-1]
            spaces = spaces[0:-1]
        else:
            spaces[-1] = False
            
        return Doc(self.vocab, words=words, spaces=spaces)

# %%
import pandas as pd

test = pd.read_csv('data/Latin_NER_test.csv', index_col=0)
len(test)
# Out:
# 31788

# %%
def f7(seq):
    seen = set()
    seen_add = seen.add
    return [x for x in seq if not (x in seen or seen_add(x))]

unqlist = f7(test['sent_id'].to_list())

dct = {unq: i for i, unq in enumerate(unqlist)}

# %%
test['to_group'] = test.sent_id.apply(lambda x: dct[x])
test.head()
# Out:
#        word     tag  sentence orig_text sent_id  to_group
# 0    timere       O        11        CW   CW_11         0
# 1  Caesarem  B-PERS        11        CW   CW_11         0
# 2   ereptis       O        11        CW   CW_11         0
# 3        ab       O        11        CW   CW_11         0
# 4        eo       O        11        CW   CW_11         0

# %%
nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)

# %%
from spacy.training import offsets_to_biluo_tags

grouped = test.groupby('to_group')

sents = [grouped.get_group(group)['word'].values.tolist() for group in grouped.groups]

labels = [grouped.get_group(group)['tag'].values.tolist() for group in grouped.groups]
print(labels)

predictions=[[(ent.start_char, ent.end_char, ent.label_) for ent in nlp(' '.join(sent)).ents] for sent in sents]
# print(predictions)
predictions=[offsets_to_biluo_tags(nlp(' '.join(sent)), predictions[i]) for i,sent in enumerate(sents)]
print(predictions)
# # [(i, text) for i,text in enumerate(test['word'])]
# Out:
# [['O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O'], ['B-PERS', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'B-PERS', 'I-PERS', 'B-PERS', 'I-PERS', 'O', 'O', 'O'], ['O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-PERS', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'B-PERS', 'O', 'O', 'O'], ['B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O'], ['O', 'O', 'B-PERS', 'O', 'B-PERS', 'B-LOC', 'O', 'O', 'O', 'B-PERS', 'O', 'O'], ['O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'], ['O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'I-PERS', 'O', 'O', 'B-PERS', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'B-PERS', 'O', 'B-GRP', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'I-PERS', 'O', 'O', 'B-PERS', 'B-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O'], ['O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'B-PERS', 'I-PERS', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-PERS', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-GRP', 'B-GRP', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'B-PERS', 'O', 'O', 'O'], ['O', 'O', 'B-LOC', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'B-LOC', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'], ['B-PERS', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-GRP', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'B-PERS', 'B-GRP', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'B-GRP', 'O', 'O', 'O', 'O'], ['O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'B-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',  ...
# [['O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-PERSON', 'O', 'O'], ['U-PERSON', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'B-PERSON', 'L-PERSON', 'B-PERSON', 'L-PERSON', 'O', 'O', 'O'], ['O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['U-PERSON', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-LOC', 'B-LOC', 'L-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'U-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'U-PERSON', 'O', 'U-PERSON', 'O', 'O', 'O'], ['U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'U-PERSON', 'O', 'O'], ['O', 'O', 'U-PERSON', 'O', 'U-PERSON', 'U-LOC', 'O', 'O', 'O', 'U-PERSON', 'O', 'O'], ['O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'U-LOC', 'O', 'O', 'O', 'O'], ['O', 'O', 'U-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['U-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-PERSON', 'U-LOC', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-LOC', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'L-PERSON', 'O', 'O', 'U-PERSON', 'O', 'O', 'U-LOC', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'U-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'L-PERSON', 'O', 'O', 'U-PERSON', 'U-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O'], ['O', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['U-PERSON', 'O', 'O', 'O', 'O', 'U-LOC', 'O', 'U-LOC', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['U-NORP', 'U-NORP', 'O', 'O', 'O', 'O', 'U-PERSON', 'O', 'O', 'U-PERSON', 'O', 'O', 'O'], ['O', 'O', 'U-LOC', 'O', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'U-LOC', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'U-LOC', 'O', 'O', 'O', 'O', 'U-LOC', 'O', 'O', 'O', 'O'], ['U-PERSON', 'O', 'U-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'U-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'U-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'U-PERSON', 'O', 'O', 'O', 'U-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', ' ...

# %%
print(sents)
# Out:
# [['timere', 'Caesarem', 'ereptis', 'ab', 'eo', 'duabus', 'legionibus', ',', 'ne', 'ad', 'eius', 'periculum', 'reservare', 'et', 'retinere', 'eas', 'ad', 'urbem', 'Pompeius', 'videretur', ';'], ['Lentulus', 'sententiam', 'Calidi', 'pronuntiaturum', 'se', 'omnino', 'negavit', ',', 'Marcellus', 'perterritus', 'conviciis', 'a', 'sua', 'sententia', 'discessit', '.'], ['intercedit', 'M.', 'Antonius', 'Q.', 'Cassius', 'tribuni', 'plebis', '.'], ['dicuntur', 'sententiae', 'graves', ';'], ['laudat', 'promptos', 'atque', 'in', 'posterum', 'confirmat', ',', 'segniores', 'castigat', 'atque', 'incitat', '.'], ['Catonem', 'veteres', 'inimicitiae', 'Caesaris', 'incitant', 'et', 'dolor', 'repulsae', '.'], ['simul', 'infamia', 'duarum', 'legionum', 'permotus', ',', 'quas', 'ab', 'itinere', 'Asiae', 'Syriaeque', 'ad', 'suam', 'potentiam', 'dominatumque', 'converterat', ',', 'rem', 'ad', 'arma', 'deduci', 'studebat', '.'], ['is', 'eo', 'tempore', 'erat', 'Ravennae', 'exspectabatque', 'suis', 'lenissimis', 'postulatis', 'responsa', ',', 'siqua', 'hominum', 'aequitate', 'res', 'ad', 'otium', 'deduci', 'posset', '.'], ['Quibus', 'rebus', 'cognitis', 'Caesar', 'apud', 'milites', 'contionatur', '.'], ['atque', 'haec', 'superioris', 'aetatis', 'exempla', 'expiata', 'Saturnini', 'atque', 'Gracchorum', 'casibus', 'docet', '.'], ['Caesarem', 'quoque', 'pro', 'sua', 'dignitate', 'debere', 'et', 'studium', 'et', 'iracundiam', 'suam', 'rei', 'publicae', 'dimittere', 'neque', 'adeo', 'graviter', 'irasci', 'inimicis', ',', 'ut', 'cum', 'illis', 'nocere', 'se', 'speret', ',', 'rei', 'publicae', 'noceat', '.'], ['pauca', 'eiusdem', 'generis', 'addit', 'cum', 'excusatione', 'Pompei', 'coniuncta', '.'], ['Acceptis', 'mandatis', 'Roscius', 'cum', 'Caesare', 'Capuam', 'pervenit', 'ibique', 'consules', 'Pompeiumque', 'invenit', ';'], ['quod', 'oppidum', 'Attius', 'cohortibus', 'introductis', 'tenebat', 'dilectumque', 'toto', 'Piceno', 'circummissis', 'senatoribus', 'habebat', '.'], ['Quibus', 'rebus', 'Romam', 'nuntiatis', 'tantus', 'repente', 'terror', 'invasit', ',', 'ut', 'cum', 'Lentulus', 'consul', 'ad', 'aperiendum', 'aerarium', 'venisset', 'ad', 'pecuniamque', 'Pompeio', 'ex', 'senatus', 'consulto', 'proferendam', ',', 'protinus', 'aperto', 'sanctiore', 'aerario', 'ex', 'urbe', 'profugeret', '.'], ['Capuae', 'primum', 'sese', 'confirmant', 'et', 'colligunt', 'dilectumque', 'colonorum', ',', 'qui', 'lege', 'Iulia', 'Capuam', 'deducti', 'erant', ',', 'habere', 'instituunt', ';'], ['quos', 'postea', 'monitus', 'ab', 'suis', ',', 'quod', 'ea', 'res', 'omnium', 'iudicio', 'reprehendebatur', ',', 'circum', 'familias', 'conventus', 'Campaniae', 'custodiae', 'causa', 'distribuit', '.'], ['relictus', 'in', 'itinere', 'cum', 'paucis', 'incidit', 'in', 'Vibullium', 'Rufum', 'missum', 'a', 'Pompeio', 'in', 'agrum', 'Picenum', 'confirmandorum', 'hominum', 'causa', '.'], ['interim', 'suos', 'cohortatus', 'tormenta', 'in', 'muris', 'disponit', 'certasque', 'cuique', 'partes', 'ad', 'custodiam', 'urbis', 'attribuit', ';'], ['Interim', 'Caesari', 'nuntiatur', 'Sulmonenses', ',', 'quod', 'oppidum', 'a', 'Corfinio', 'vii', 'milium', 'intervallo', 'abest', ',', 'cupere', 'ea', 'facere', 'quae', 'vellet', ',', 'sed', 'a', 'Q.', 'Lucretio', 'senatore', 'et', 'Attio', 'Paeligno', 'prohiberi', ',', 'qui', 'id', 'oppidum', 'vii', 'cohortium', 'praesidio', 'tenebant', '.'], ['Caesar', 'primis', 'diebus', 'castra', 'magnis', 'operibus', 'munire', 'et', 'ex', 'finitimis', 'municipiis', 'frumentum', 'comportare', 'reliquasque', 'copias', 'exspectare', 'instituit', '.'], ['neque', 'vero', 'tam', 'remisso', 'ac', 'languido', 'animo', 'quisquam', 'omnium', 'fuit', ',', 'qui', 'ea', 'nocte', 'conquieverit', '.'], ['cum', 'eo', 'de', 'salute', 'sua', 'orat', 'atque', 'obsecrat', 'ut', 'sibi', 'parcat', 'veteremque', 'amicitiam', 'commemorat', 'Caesarisque', 'in', 'se', 'beneficia', 'exponit', ',', 'quae', 'erant', 'maxima', 'quod', 'per', 'eum', 'in', 'collegium', 'pontificum', 'venerat', ',' ...

# %%
print(labels)
# Out:
# [['O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O'], ['B-PERS', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'B-PERS', 'I-PERS', 'B-PERS', 'I-PERS', 'O', 'O', 'O'], ['O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-PERS', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'B-PERS', 'O', 'O', 'O'], ['B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O'], ['O', 'O', 'B-PERS', 'O', 'B-PERS', 'B-LOC', 'O', 'O', 'O', 'B-PERS', 'O', 'O'], ['O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'], ['O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'I-PERS', 'O', 'O', 'B-PERS', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'B-PERS', 'O', 'B-GRP', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'I-PERS', 'O', 'O', 'B-PERS', 'B-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O'], ['O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'B-PERS', 'I-PERS', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-PERS', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-GRP', 'B-GRP', 'O', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'B-PERS', 'O', 'O', 'O'], ['O', 'O', 'B-LOC', 'O', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'B-LOC', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'], ['B-PERS', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-GRP', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'B-PERS', 'B-GRP', 'O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'B-GRP', 'O', 'O', 'O', 'O'], ['O', 'O', 'B-PERS', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'B-GRP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',  ...

# %%
predictions=[y.replace("U-", "B-").replace("L-", "I-") for x in predictions for y in x]
print(predictions)
# Out:
# ['O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'B-PERSON', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'B-PERSON', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'B-PERSON', 'B-LOC', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'B-PERSON', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'B-PERSON', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-NORP', 'B-NORP', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'B-LOC', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON ...

# %%
len(predictions)
# Out:
# 31788

# %%
predictions = [pred.replace('PERSON', 'PERS') for pred in predictions]
predictions = [pred.replace('NORP', 'GRP') for pred in predictions]
true = [tag for word in labels for tag in word]

from sklearn.metrics import classification_report

report=classification_report(true, predictions)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#        B-GRP       0.23      0.01      0.02       354
#        B-LOC       0.42      0.62      0.50       305
#       B-PERS       0.55      0.71      0.62       849
#        I-GRP       0.00      0.00      0.00         3
#        I-LOC       0.00      0.00      0.00         8
#       I-PERS       0.74      0.29      0.42        99
#            O       0.98      0.98      0.98     30170
#
#     accuracy                           0.96     31788
#    macro avg       0.42      0.37      0.36     31788
# weighted avg       0.96      0.96      0.96     31788
# C:\Users\u0161477\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\u0161477\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\u0161477\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
report=classification_report(true, predictions)
# Out:
# C:\Users\u0161477\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\u0161477\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\u0161477\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        B-GRP       0.23      0.01      0.02       354
#        B-LOC       0.42      0.62      0.50       305
#       B-PERS       0.55      0.71      0.62       849
#        I-GRP       0.00      0.00      0.00         3
#        I-LOC       0.00      0.00      0.00         8
#       I-PERS       0.74      0.29      0.42        99
#            O       0.98      0.98      0.98     30170
#
#     accuracy                           0.96     31788
#    macro avg       0.42      0.37      0.36     31788
# weighted avg       0.96      0.96      0.96     31788

# %%
test['predictions'] = predictions

# %%
test['true_spacy'] = true

# %%
test
# Out:
#            word     tag  sentence orig_text    sent_id  to_group predictions
# 0        timere       O        11        CW      CW_11         0           O  \
# 1      Caesarem  B-PERS        11        CW      CW_11         0      B-PERS
# 2       ereptis       O        11        CW      CW_11         0           O
# 3            ab       O        11        CW      CW_11         0           O
# 4            eo       O        11        CW      CW_11         0           O
# ...         ...     ...       ...       ...        ...       ...         ...
# 31783         .       O      2433      Ovid  Ovid_2433      3408           O
# 31784       Quo       O      2434      Ovid  Ovid_2434      3409           O
# 31785     feror       O      2434      Ovid  Ovid_2434      3409           O
# 31786   insanus       O      2434      Ovid  Ovid_2434      3409           O
# 31787         ?       O      2434      Ovid  Ovid_2434      3409           O
#
#       true_spacy
# 0              O
# 1         B-PERS
# 2              O
# 3              O
# 4              O
# ...          ...
# 31783          O
# 31784          O
# 31785          O
# 31786          O
# 31787          O
#
# [31788 rows x 8 columns]

# %%
# test.to_csv('spacy_errors_test.csv')
orig_test = pd.read_csv('spacy_errors_test.csv', index_col=0)

# %%
compare_df = orig_test.compare(test, keep_equal=True, keep_shape=True)

# %%
compare_df.columns
# Out:
# MultiIndex([(       'word',  'self'),
#             (       'word', 'other'),
#             (        'tag',  'self'),
#             (        'tag', 'other'),
#             (   'sentence',  'self'),
#             (   'sentence', 'other'),
#             (  'orig_text',  'self'),
#             (  'orig_text', 'other'),
#             (    'sent_id',  'self'),
#             (    'sent_id', 'other'),
#             (   'to_group',  'self'),
#             (   'to_group', 'other'),
#             ('predictions',  'self'),
#             ('predictions', 'other'),
#             ( 'true_spacy',  'self'),
#             ( 'true_spacy', 'other')],
#            )

# %%
# len(orig_test)
# Out:
# 31788

# %%
orig_test.columns
# Out:
# Index(['Unnamed: 0', 'word', 'tag', 'sentence', 'orig_text', 'sent_id',
#        'to_group', 'predictions', 'true_spacy'],
#       dtype='object')
